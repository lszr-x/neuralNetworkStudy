# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randn
# plt.plot(np.arange(10))

# %%
from datetime import datetime as dt
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
data=pd.read_csv('.csv',index_col=0,parse_dates=True)
spx=data['SPX']
spx.plot(ax=ax,style='k-')

crisis_data=[
    (datatime(2008,3,12),'注释')
]
for date label in crisis_data:
    ax.annotate(label,xy=(data,spx.asof(date)+50),
               xytext=(data,spx.asof(date)+100),
               arrowprops=dict(facecolor='black'),
               horizontalalignment='left',
               verticalalignment='top')

    
ax.set_xlim()

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum(),'k',label='one')
ax.plot(randn(1000).cumsum(),'k--',label='two')
ax.plot(randn(1000).cumsum(),'k.',label='three')
ax.legend(loc='best')

# %%
# a=plt.xlim()
# print(a)

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
ax.plot(randn(1000).cumsum())
ticks=ax.set_xticks([0,250,500,750,1000])
labels=ax.set_xticklabels(['one','two','three'],rotation=30,fontsize='small')
ax.set_title('fist plot')
ax.set_xlabel('xName')
ax.set_ylabel('yName')
# Out:
# Text(0,0.5,'yName')

# %%
from numpy.random import randn
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
ax3.plot(randn(50).cumsum(),'k')

ax1.hist(randn(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(30),np.arange(30)+3*randn(30))

# %%
fig,axes=plt.subplots(2,3,sharex=True,sharey=True)
plt.subplots_adjust(left=None,bottom=None,right=None,top=None,wspace=0,hspace=0)
for i in range(2):
    for j in range(3):
        axes[i,j].hist(randn(50),bins=10,color='k',alpha=0.9)
# axes

# %%
x=[1,2,3,4,5,6]
y=[11,23,4,6,7,11]
fig,axes=plt.subplots(1,1)
axes.plot(x,y,'g--',marker='o')
axes.plot(y,x,linestyle='--',marker='o',color='r')
data=randn(30).cumsum()
plt.plot(data,'k',drawstyle='steps-post',label='steps-post')
plt.legend(loc='best')
