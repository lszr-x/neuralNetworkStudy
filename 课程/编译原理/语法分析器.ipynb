# %%
str1=['eadeaa##','edeaebd##','edeaeaadabacae##']
print("计科160508 邢鼎威 20167482")
def Parser():
    for i in range(100):
        str1=input()
        flag,str4=E(str1)
        if flag is True:
            print('正确')
        else:
            print('错误')
def E(string):
    flag=True
    str3=''
    if string[0] is 'e':
        flag,str3=B(string[1:])
        if flag is False:
            return False,'###'
        else:
            if str3[0] is 'a':
                flag,str3=A(str3[1:])
                if flag is False:
                    return False,'###'
                else:
                    return True,str3
            else:
                return False,'###'
    else:
        return False,'###'
    

def A(string):
    flag=True
    str3=''
    if string[0] is 'a':
        return True,string[1:]
    elif string[0] is 'b':
        flag,str3=A(string[1:])
        if flag is False:
            return False,'###'
        else:
            if str3[0] is 'c':
                flag,str3=B(str3[1:])
                if flag is False:
                    return False,'###'
                else:
                    return True,str3
    else:
        return False
    
def B(string):
    flag=True
    str3=''
    if string[0] is 'a':
        flag,str3=C(string[1:])
        if flag is False:
            return False,'###'
        else:
            return True,str3
    elif string[0] is 'd':
        flag,str3=E(string[1:])
        if flag is False:
            return False,'###'
        else:
            if str3[0] is 'd':
                return True,str3[1:]
            else:
                return False,'###'
    else:
        return False,'###'
def C(string):
    flag=True
    str3=''
    if string[0] is 'e':
        return True,string[1:]
    elif string[0] is 'd':
        flag,str3=C(string[1:])
        if flag is False:
            return False,'###'
        else:
            return True,str3
    else:
        return False,'###'
    
Parser()
# Out:
# 计科160508 邢鼎威 20167482
# eadeaa##
# 正确
# edeaebd##
# 错误
# edeaeaadabacae##
# 正确
